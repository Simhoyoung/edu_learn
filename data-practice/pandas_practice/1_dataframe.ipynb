# %%
import pandas as pd

# as : 별칭

# %%
# 데이터프레임으로 만들 데이터 생성
data = {
    # 열 내부의 데이터 타입은 동일하다.
    "name": ["코딩민수", "축구민수", "곤충민수", "술민수"],
    "age": [16, 19, 22, '100살'], # 동일한 데이터타입으로 바꿔준다
}

# pandas 데이터프레임 객체 생성
df = pd.DataFrame(data)
df
# 리스트 [] list()
# 딕셔너리 {} dict()
# 튜플 () tuple()
# 셋 set()

# %%
# 데이터프레임으로 만들 데이터 생성
data = {
    # 열 내부의 데이터 타입은 동일하다.
    "name": ["jay", "anna", "peter", "linda"],
    "age": [28, 34, 29, 32], 
    "salary": [50000, 62000, 58000, 75000]
}

# pandas 데이터프레임 객체 생성
df = pd.DataFrame(data)
df
# 리스트 [] list()
# 딕셔너리 {} dict()
# 튜플 () tuple()
# 셋 set()

# %%
# Details API 요청, 영화 정보 저장
# 영화 정보를 가지고, data 변수 생성
# 열(colum) : id, overview, title, release_date
# data 변수로 데이터프레임 생성

import requests
from pprint import pprint

movie_id = 912649

api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'
base_url = "https://api.themoviedb.org/3"
endpoint = f"/movie/{movie_id}"
requests_url = base_url + endpoint

params = {"language": "ko-KR"}

headers = {
    "Authorization": f"Bearer {api_token}",
}

response = requests.get(requests_url, headers=headers, params=params).json()
# print(type(response))
pprint(response)

id = response["id"]
overview = response["overview"]
title = response["title"]
release_date = response["release_date"]

data = [
    {
        "id": id,
        "overview": overview,
        "title": title,
        "release_date": release_date,
    }
]

print(type(data))
pprint(data)
df = pd.DataFrame(data)
df
# Out:
# {'adult': False,
#  'backdrop_path': '/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg',
#  'belongs_to_collection': {'backdrop_path': '/vq340s8DxA5Q209FT8PHA6CXYOx.jpg',
#                            'id': 558216,
#                            'name': '베놈 시리즈',
#                            'poster_path': '/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg'},
#  'budget': 120000000,
#  'genres': [{'id': 28, 'name': '액션'},
#             {'id': 878, 'name': 'SF'},
#             {'id': 12, 'name': '모험'},
#             {'id': 53, 'name': '스릴러'}],
#  'homepage': '',
#  'id': 912649,
#  'imdb_id': 'tt16366836',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Venom: The Last Dance',
#  'overview': '환상의 케미스트리의 에디 브록과 그의 심비오트 베놈은 그들을 노리는 정체불명 존재의 추격을 피해 같이 도망을 다니게 '
#              '된다. 한편 베놈의 창조자 널은 고향 행성에서부터 그들을 찾아내기 위해 지구를 침략하고 에디와 베놈은 그동안 '
#              '겪어보지 못한 최악의 위기를 맞이하게 되는데…',
#  'popularity': 6191.971,
#  'poster_path': '/rajTvnpDKRupZPpKJRxeJMKrIs6.jpg',
# ...

# %%
import requests
from pprint import pprint

api_token = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3YmY4ZjNlNDVmZDIzNWZkOTljMjA4YjYxZGNmZGVjYSIsIm5iZiI6MTU2ODg3Njk5MS4wMSwic3ViIjoiNWQ4MzI5YmYxNjJiYzMwMjI3ZGRmY2Q2Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.iBc4VQRVQSZxYEynfP254OHkvSyZNxD0w9I-ge6jJQw"
base_url = "https://api.themoviedb.org/3"

endpoint = f"/movie/now_playing"
request_url = base_url + endpoint
params = {"language": "ko-KR"}
headers = {
    "Authorization": f"Bearer {api_token}",
}

response = requests.get(request_url, headers=headers, params=params).json()
movie_list = response["results"]
# print(type(movie_list))
pprint(len(movie_list))
"""
data = [
    {
        "id": id,
        "overviwe": overview,
        "title": title,
        "release_date": release_date,
    }
]
"""
# 개별 영화 정보를 저장할 리스트
# 즉, 데이터프레임의 기반 데이터가 될 리스트
data = []
for movie in movie_list:
    # print(movie)
    # 개별 영화 정보에서 필요한 데이터만 추출하는 과정
    id = movie["id"]
    overview = movie["overview"]
    title = movie["title"]
    release_date = movie["release_date"]

    # 개별 영화 정보를 쌓는 과정
    data.append(
        {
            "id": id,
            "overviwe": overview,
            "title": title,
            "release_date": release_date,
        }
    )

# print(len(data))
df = pd.DataFrame(data)
df

# %%
import pandas as pd

df = pd.read_csv("./a/winequality-red.csv")

df

# %%
data = {
    # 열 내부의 데이터 타입은 동일하다.
    "name": ["Jay", "Anna", "Peter", "Linda"],
    "age": [28, 34, 29, 32], 
    "salary": [50000, 62000, 58000, 75000]
}

df = pd.DataFrame(data)
# 저장하고 싶은 데이터프레임.to_파일형식
df.to_csv("example.csv")

# %%
# requests 라이브러리 불러오기
import requests

# 오픈 API Key
serviceKey = "ET+3wWGAkaXNNboJcj780MPyaOj+YTGC8qDEASKdCMILG76Z7Ulw43lhrVR3kSQKkUcmLrGNWimwMf4hqzDlrA=="

# API url = base_url + endpoint
base_url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc"
endpoint = "/getMinuDustWeekFrcstDspth"

# 요청 url 조합
request_url = base_url + endpoint

# 언제, 어디서
searchDate = "2024-12-16"
# sidoName = 

# 응답 데이터 형식 관련된 요청 변수
pageNo = 1
numOfRows = 100
returnType = "json"  # 응답 데이터의 포맷(형태)

params = {
    "serviceKey": serviceKey,
    "numOfRows": numOfRows,
    "pageNo": pageNo,
    "returnType": returnType,
    "searchDate": searchDate,
}

# API 요청
response = requests.get(request_url, params=params).json()['response']['body']['items']
# print(response)
from pprint import pprint
# pprint(response)


data = []
for i in response:
    data.append(
        {
            "frcstFourCn": i["frcstFourCn"],
            "frcstFourDt": i["frcstFourDt"], 
            "frcstOneCn": i["frcstOneCn"], 
            "frcstOneDt": i["frcstOneDt"], 
            "gwthcnd": i["gwthcnd"], 
        }
    )
import pandas as pd
# print(type(data))
df = pd.DataFrame(data)
df.to_csv("../openapi_day01.csv")
df
# Out:
#                                          frcstFourCn frcstFourDt  \
# 0  서울 : 낮음, 인천 : 낮음, 경기북부 : 낮음, 경기남부 : 낮음, 강원영서 :...  2024-12-22
#
#                                           frcstOneCn  frcstOneDt  \
# 0  서울 : 낮음, 인천 : 낮음, 경기북부 : 낮음, 경기남부 : 낮음, 강원영서 :...  2024-12-19
#
#                                              gwthcnd
# 0  [12월19일, 22일] 원활한 대기 확산과 강수의 영향(22일)으로 전 권역에서 ...
