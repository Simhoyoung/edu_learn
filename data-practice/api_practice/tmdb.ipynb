# %%
# API KEY 활용 코드
import requests
api_key = '953e962b9277fa0490b5eb87da565884'

# 요청주소 =
# base_url + endpoint
base_url = 'https://api.themoviedb.org/3'
endpoint = '/movie/now_playing'
requests_url = base_url + endpoint

# 쿼리 파라미터 : 노출됨,보여짐,보안(하)
params = {
    'api_key': api_key,
    'language': 'ko-KR',
}

# header : 데이터를 나타내는 데이터
# accept : 응답 받고 싶은 데이터를 명시
headers = {'accept' : 'application/json'}

# requests.get(requests_url)
response_data = requests.get(requests_url, params=params, headers=headers)
print(response_data)

# %%
from pprint import pprint

response_python = response_data.json()
pprint(response_python['results'])

# %%
# API Token 

# TMDB API Token
api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'

# 요청 주소 =
base_url = "https://api.themoviedb.org/3"
endpoint = "/movie/now_playing"
response_url = base_url + endpoint

# 헤더에 토큰 명시
headers = {
    #인증 정보
    #Bearer {API Token}
    "Authorization": f"Bearer {api_token}",
}

response_data = requests.get(response_url, headers=headers)
pprint(response_data.json())

# %%
# Favorite Movies 요청 및 결과 출력 코드
# api token(읽기 액세스 토큰) 방식 활용

# 요청을 위한 필수 데이터
api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'
account_id = 21692299

# 요청 url
# base_url + endpoint

base_url = "https://api.themoviedb.org/3"
# {} 리터럴 : 가변적 데이터
# f-string : 문자열 중간에 변수 넣는 문법
endpoint = f"/account/{account_id}/favorite/movies"
requests_url = base_url + endpoint

headers = {
    "Authorization": f"Bearer {api_token}",
}

response_data = requests.get(requests_url, headers=headers)
pprint(response_data.json())

# %%
# 쿼리 파라미터와 헤더는무조건 있어야하는 요소는 아니다
# 단, api 설계자가 쿼리 파라미터로 특정 데이터를 요구하는 경우 -> 쿼리 파라미터 필수

# API KEY를 사용한다 -> 헤더가 필요없다? X
# API Token을 사용한다 -> 쿼리 파라미터가 필요없다? X

# %%
# Details 요청 및 결과 출력 코드
# api token(읽기 액세스 토큰) 방식 활용

# 요청을 위한 필수 데이터
api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'
movie_id = 9091

# 요청 url
# base_url + endpoint

base_url = "https://api.themoviedb.org/3"
# {} 리터럴 : 가변적 데이터
# f-string : 문자열 중간에 변수 넣는 문법
endpoint = f"/movie/{movie_id}"
requests_url = base_url + endpoint

# 쿼리 필요하면 params
params = {"language": "ko-KR"}

# token이 저장된 headers
headers = {
    "Authorization": f"Bearer {api_token}",
}

response_data = requests.get(requests_url, headers=headers, params=params)
pprint(response_data.json())
# Out:
# {'adult': False,
#  'backdrop_path': '/3QBW1kwihXnqhuxtVlQRHuPeYvf.jpg',
#  'belongs_to_collection': None,
#  'budget': 35000000,
#  'genres': [{'id': 28, 'name': '액션'},
#             {'id': 18, 'name': '드라마'},
#             {'id': 53, 'name': '스릴러'}],
#  'homepage': '',
#  'id': 9091,
#  'imdb_id': 'tt0114576',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Sudden Death',
#  'overview': '소방수로 근무하던 대런 멕코드(장 끌로드 반담)는 어느날 대형 화재 사건에서 어린 소녀를 구하기 위해 필사적으로 '
#              '노력하지만 품안에서 끝내 숨지고 만다. 그 이후로 자신의 불찰에 대한 자책감으로 소방수를 그만 두고 하키 경기장의 '
#              '화재 감시원으로 일하게 된다. 화재 사건의 충격으로 가족들과도 떨어져 살게 된 그는 피츠버그 펭귄팀의 최종결승전 '
#              '7차전 하키경기 티켓을 구해 오랜만에 그의 아들과 딸을 데리고 경기장에 간다. 아빠가 과거에는 자랑스러운 '
#              '소방수였지만 지금은 경기장의 화재감시원으로 경기장의 전구나 갈러다니는 것을 본 아들 타일러(로스 말린거)는 아빠가 '
#              '실망스럽기만 하다. 괜히 동생 에밀리(휘트니 라이트)에게 화를 내게 되고 오빠의 성화에 화가 난 에밀리는 자리를 '
#              '떠나지 말고 꼭 앉아 있으라는 아빠의 말을 어기고 뛰쳐 나가게 된다. 마침 경기장에는 부통령이 결승전을 구경하고자 '
#              '참관했는데 수많은 경비원들이 삼엄하게 경비를 서고 있었으나 이미 테러리스트들이 침입해 이 경기를 관전 중인 부통령과 '
#              '귀빈들을 인질로 잡는다. 그들의 목적은 정부가 다른 나라 은행에 동결시켜 놓은 엄청난 액수의 돈을 챙기는데 있었다. '
#              '화가 나서 뛰쳐나온 에밀리는 뜻밖의 살인 장면을 목격하고 엉겹결에 인질이 되어버린다. 딸이 인질로 납치된 것을 알게 '
#              '된 맥코드는 수많은 경찰들과 경찰차들이 에워싸고 있는 가운데 홀로 테러리스트와 쫓고 쫓기는 게임을 벌인다. '
#              '테러리스트 두목과의 하키 결승골을 계산에 둔 치열한 두뇌 싸움과 손에 땀을 쥐게하는 혈전 끝에 맥코드는 부통령과 '
#              '딸을 구하고 아빠에게 실망했던 아들 타일러에게서 다시금 존경심을 되찾게 된다.',
#  'popularity': 14.523,
#  'poster_path': '/qAt8PBbqzzA6pttEHxHRRYVIDih.jpg',
#  'production_companies': [{'id': 99689,
#                            'logo_path': None,
#                            'name': 'Shattered Productions',
#                            'origin_country': 'US'},
#                           {'id': 33,
#                            'logo_path': '/3wwjVpkZtnog6lSKzWDjvw2Yi00.png',
#                            'name': 'Universal Pictures',
#                            'origin_country': 'US'},
#                           {'id': 21437,
#                            'logo_path': '/4JzGnT8XGMrdGHHOfVaMNNKLZAp.png',
#                            'name': 'Imperial Entertainment',
#                            'origin_country': 'US'},
#                           {'id': 23770,
#                            'logo_path': '/t1Dc5SaJLBfRxtl0ttLGdaYICQ2.png',
#                            'name': 'Signature Entertainment',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1995-10-27',
#  'revenue': 64350171,
#  'runtime': 110,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': '서든 데쓰',
#  'video': False,
#  'vote_average': 6.0,
#  'vote_count': 715}

# %%
# Search Movies 요청 및 결과 출력 코드
# api token(읽기 액세스 토큰) 방식 활용

# 요청을 위한 필수 데이터
api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'

# 요청 url
# base_url + endpoint

base_url = "https://api.themoviedb.org/3"
# {} 리터럴 : 가변적 데이터
# f-string : 문자열 중간에 변수 넣는 문법
endpoint = "/search/movie"
requests_url = base_url + endpoint

movie_name = input()

params = {
    "language": "ko-KR",
    "query": movie_name,
}

headers = {
    "Authorization": f"Bearer {api_token}",
}

response_data = requests.get(requests_url, headers=headers, params=params)
pprint(response_data.json())
# Out:
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}

# %%
# 현재 인기있는 영화, TV 프로그램, 인물을 응답하는 API 찾아서 요청
# day / week

# Search Movies 요청 및 결과 출력 코드
# api token(읽기 액세스 토큰) 방식 활용

# 요청을 위한 필수 데이터
api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'
time_window = 'week'

# 요청 url
# base_url + endpoint

base_url = "https://api.themoviedb.org/3"
# {} 리터럴 : 가변적 데이터
# f-string : 문자열 중간에 변수 넣는 문법
endpoint = f"/trending/all/{time_window}"
requests_url = base_url + endpoint

params = {
    "language": "ko-KR",
    "time_window": time_window,
}

headers = {
    "Authorization": f"Bearer {api_token}",
}

response_data = requests.get(requests_url, headers=headers, params=params)
pprint(response_data.json())

# %%
#상영중인 영화정보

api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'

base_url = "https://api.themoviedb.org/3"
endpoint = "/movie/now_playing"
requests_url = base_url + endpoint

params = {
    "language": "ko-KR",
}

headers = {
    "Authorization": f"Bearer {api_token}",
}

response_data = requests.get(requests_url, headers=headers, params=params)
pprint(response_data.json()['results'])

# %%
results = response_data.json()['results']
print(len(results)) #page 당 영화정보 갯수
pprint(results[:3])

# %%
#상영중인 영화정보 page 1~5

api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'

base_url = "https://api.themoviedb.org/3"
endpoint = "/movie/now_playing"
requests_url = base_url + endpoint

# 1~5page 영화정보를 저장할 리스트
results_list = []

for page in range(1, 6):
    params = {
        "language": "ko-KR",
        "page": page,
    }

    headers = {
        "Authorization": f"Bearer {api_token}",
    }

    response_data = requests.get(requests_url, headers=headers, params=params)
    results = response_data.json()['results']

    # 영화 정보 리스트에 영화 정보를 저장
    # results_list.append(results)

    # 리스트.extend(입력 리스트) : 입력 리스트를 풀어서 리스트에 추가
    results_list.extend(results)

# print(len(results_list))
# pprint(results_list)

max_vote = results_list[0]['vote_average']
max_movie = results_list[0]

for movie in results_list:
    #개별 영화의 평균 평점
    vote = movie['vote_average']

    if max_vote < vote:
        max_vote = vote
        max_movie = movie

# 최대 평균 평점 영화의 제목과 평균 평점
print(max_movie["title"])
print(max_movie["vote_average"])

# for i in results_list:
#     # pprint(i['vote_average'])

#     if max_avg < i['vote_average'] :
#         max_avg = i['vote_average']
#         max_name = i['title']

# pprint(max_avg)
# print(max_name)
# Out:
# 미라클 월드 런던: 시간의 끝에서
# 8.5

# %%
#상영중인 영화정보

api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTNlOTYyYjkyNzdmYTA0OTBiNWViODdkYTU2NTg4NCIsIm5iZiI6MTczNDQwNTQzNS4wNTksInN1YiI6IjY3NjBlZDNiYjFhYjEwYzAxMGJiMDA1YSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oFQ9rFisfLd4SinenHZYGmKXQSIiXALz8m4xJ7jerA'

base_url = "https://api.themoviedb.org/3"
endpoint = "/movie/now_playing"
requests_url = base_url + endpoint

params = {
    "language": "ko-KR",
}

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {api_token}",
}

response_data = requests.get(requests_url, headers=headers, params=params)
results = response_python["results"]

# 평가가 좋은 영화 중 첫 번째 영화
top_movie = results[0]

# 최고 평가 영화의 movie_id 추출
move_id = top_movie["id"]

pprint(movie_id)

# 영화의 review를 요청하는 주소url
base_url = "https://api.themoviedb.org/3"
endpoint = f"/movie/{movie_id}/reviews"
requests_url = base_url + endpoint

response_reviews = requests.get(requests_url, headers=headers)
pprint(response_reviews.json())
# Out:
# 9091
# {'id': 9091, 'page': 1, 'results': [], 'total_pages': 0, 'total_results': 0}
